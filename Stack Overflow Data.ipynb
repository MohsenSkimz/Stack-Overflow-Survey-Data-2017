# %% [markdown]
# # Business Understanding
# - What are Top 5 Languages worked by professional?
# - Whte are Most country that have People used JavaScript?
# - Whte are Most IDE That Used By United States?

# %% [markdown]
# # Data Understanding
#
# In this section of the report, i will load the data and take some insights

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#Read in the dataset and take a look at the first few rows here:
df = pd.read_csv("survey_results_public.csv")
df_info = pd.read_csv('survey_results_schema.csv')

# %%
df.head()
# Out:
#    Respondent                                       Professional  \
# 0           1                                            Student
# 1           2                                            Student
# 2           3                             Professional developer
# 3           4  Professional non-developer who sometimes write...
# 4           5                             Professional developer
#
#                 ProgramHobby         Country      University  \
# 0                  Yes, both   United States              No
# 1                  Yes, both  United Kingdom  Yes, full-time
# 2                  Yes, both  United Kingdom              No
# 3                  Yes, both   United States              No
# 4  Yes, I program as a hobby     Switzerland              No
#
#                          EmploymentStatus  \
# 0  Not employed, and not looking for work
# 1                      Employed part-time
# 2                      Employed full-time
# ...

# %%
df_info
# Out:
#                           Column  \
# 0                     Respondent
# 1                   Professional
# 2                   ProgramHobby
# 3                        Country
# 4                     University
# 5               EmploymentStatus
# 6                FormalEducation
# 7                 MajorUndergrad
# 8                     HomeRemote
# 9                    CompanySize
# 10                   CompanyType
# 11                  YearsProgram
# 12                 YearsCodedJob
# 13             YearsCodedJobPast
# 14                 DeveloperType
# 15              WebDeveloperType
# 16           MobileDeveloperType
# 17              NonDeveloperType
# 18            CareerSatisfaction
# 19               JobSatisfaction
# 20                 ExCoderReturn
# 21               ExCoderNotForMe
# 22                ExCoderBalance
# 23                ExCoder10Years
# 24               ExCoderBelonged
# 25                 ExCoderSkills
# 26            ExCoderWillNotCode
# ...

# %%
#Use .info()to get some insights:
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51392 entries, 0 to 51391
# Columns: 154 entries, Respondent to ExpectedSalary
# dtypes: float64(6), int64(1), object(147)
# memory usage: 60.4+ MB

# %%
#Use describe()to get some insights:
df.describe()
# Out:
#          Respondent  CareerSatisfaction  JobSatisfaction  HoursPerWeek  \
# count  51392.000000        42695.000000     40376.000000  20600.000000
# mean   25696.500000            7.300574         6.957078      3.952282
# std    14835.736854            1.955444         2.167652      7.564722
# min        1.000000            0.000000         0.000000      0.000000
# 25%    12848.750000            6.000000         6.000000      1.000000
# 50%    25696.500000            8.000000         7.000000      1.000000
# 75%    38544.250000            9.000000         8.000000      4.000000
# max    51392.000000           10.000000        10.000000     40.000000
#
#        StackOverflowSatisfaction         Salary  ExpectedSalary
# count               36592.000000   12891.000000     2566.000000
# mean                    8.429875   56298.480641    33142.220468
# std                     1.390635   39880.905277    30162.988829
# min                     0.000000       0.000000        0.000000
# ...

# %% [markdown]
# # Data Preparation:
# This section will be used to prepare and clean the data for further analysis.

# %%
#Show How many missing values in the dataset? 
df.isna().sum()
# Out:
# Respondent                         0
# Professional                       0
# ProgramHobby                       0
# Country                            0
# University                         0
# EmploymentStatus                   0
# FormalEducation                    0
# MajorUndergrad                  8551
# HomeRemote                      7384
# CompanySize                    12470
# CompanyType                    12569
# YearsProgram                     247
# YearsCodedJob                  10502
# YearsCodedJobPast              50418
# DeveloperType                  15267
# WebDeveloperType               40696
# MobileDeveloperType            49839
# NonDeveloperType               46502
# CareerSatisfaction              8697
# JobSatisfaction                11016
# ExCoderReturn                  50469
# ExCoderNotForMe                50471
# ExCoderBalance                 50469
# ExCoder10Years                 50475
# ExCoderBelonged                50464
# ...

# %%
df['HaveWorkedLanguage'].isnull().sum()
# Out:
# 14767

# %% [markdown]
# There are "14767" values in "HaveWorkedLanguage" column and we need to drop them because i will use this column. i will drop them to improve performance and accuracy for our analysis.';,'lm,l;mkl;m klnjlnljnjlnljlnjlnl

# %%
#drop the null values:
new_df = df.dropna(how='any')

# %%
#check the null values:
new_df['HaveWorkedLanguage'].isnull().sum()
# Out:
# 0

# %%
#see how many diplicated rows:
new_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Q1
# ### What are Top 5 Languages worked by professional?

# %%
## Create a function that visualizes two columns of bar charts for top 5 languages worked by Student, Professional developer
def plot_top_languages(df, professional):
    '''
    INPUT:
    df - the pandas dataframe
    professional - visualize Student and Professional developer 

    OUTPUT:
    bar chart of top 5 languages worked by the professionals
    '''
    top_lang_professional = df["HaveWorkedLanguage"][df["Professional"] == professional].str.split(';', expand=True).stack().value_counts()
    fig_dims = (13,5)
    fig, ax = plt.subplots(figsize=fig_dims)
    sns.barplot(x=top_lang_professional[:5].index, y=top_lang_professional[:5].values).set(title='Top 5 Languages worked by professional  {}'.format(professional))

    plt.xlabel("Language", labelpad=15)
    plt.ylabel("Number of {}".format(professional), labelpad=15)

# Create a for loop that calls the function for each country
for professional in ["Student","Professional developer"]:
    plot_top_languages(df, professional)

# %% [markdown]
# Like we see in frist bar chart for Student the top languages are JavaScript,python,java,SQL and PHP ,that Because theses languages are taught in University and schools , in other side for Professional developer the top languages are SQL,JavaScript,C#,python and PHP .

# %% [markdown]
# ## Q2
# ### Whte are Most country that have People used JavaScript ?

# %%
JavaScript_list = df[df["HaveWorkedLanguage"] == "JavaScript"]["Country"].str.split(';', expand=True)
JavaScript_list.head()
# Out:
#                   0
# 16   United Kingdom
# 33           Brazil
# 50           Israel
# 65           Poland
# 182  United Kingdom

# %%
JavaScript_country= JavaScript_list.stack().value_counts()

# %%
JavaScript_country.head().plot(kind='bar', figsize=(10, 5), rot=0)
plt.xlabel("Country", labelpad=15)
plt.ylabel("Number of People there use JavaScript ", labelpad=15)
plt.title("Most country that have People used JavaScript  ", y=1);

# %% [markdown]
# in the bar chart the most country that used JavaScript is United States then United kingdom then India

# %% [markdown]
# ## Q3
# ### Whte are Most IDE That Used By United States ?

# %%
JavaScript_list = df[df["Country"] == "United States"]["IDE"].str.split(';', expand=True)
JavaScript_list.head()
# Out:
#                0                   1                    2     3   \
# 0            Atom               Xcode                 None  None
# 3       Notepad++        Sublime Text             TextMate   Vim
# 6    Sublime Text   IPython / Jupyter   Visual Studio Code  None
# 10  Visual Studio                None                 None  None
# 15      Notepad++       Visual Studio                 None  None
#
#                     4          5         6       7     8     9     10    11  \
# 0                 None       None      None    None  None  None  None  None
# 3    IPython / Jupyter   NetBeans   PyCharm   Xcode  None  None  None  None
# 6                 None       None      None    None  None  None  None  None
# 10                None       None      None    None  None  None  None  None
# 15                None       None      None    None  None  None  None  None
#
#       12    13    14
# 0   None  None  None
# 3   None  None  None
# 6   None  None  None
# 10  None  None  None
# ...

# %%
JavaScript_country= JavaScript_list.stack().value_counts()

# %%
JavaScript_country.head().plot(kind='bar', figsize=(10, 5), rot=0)
plt.xlabel("IDE", labelpad=15)
plt.ylabel("Number of People", labelpad=15)
plt.title("Most IDE That Used By United States ", y=1);

# %% [markdown]
# So in this bar chart we see in this bar chart that most of the IDE that the US is using is Visual Studio .
